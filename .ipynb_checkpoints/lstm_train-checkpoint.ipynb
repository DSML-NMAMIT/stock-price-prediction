# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('nifty_data.csv')
df.tail()
# Out:
#                           Date          Open          High           Low  \
# 487  2024-09-25 00:00:00+05:30  25899.449219  26032.800781  25871.349609
# 488  2024-09-26 00:00:00+05:30  26005.400391  26250.900391  25998.400391
# 489  2024-09-27 00:00:00+05:30  26248.250000  26277.349609  26151.400391
# 490  2024-09-30 00:00:00+05:30  26061.300781  26134.699219  25794.099609
# 491  2024-10-01 00:00:00+05:30  25788.449219  25907.599609  25739.199219
#
#             Close  Volume  Dividends  Stock Splits  Previous Close  \
# 487  26004.150391  278500        0.0           0.0        25810.85
# 488  26216.050781  370900        0.0           0.0        25810.85
# 489  26178.949219  490300        0.0           0.0        25810.85
# 490  25810.849609  343100        0.0           0.0        25810.85
# 491  25796.900391  247400        0.0           0.0        25810.85
#
#      52-Week High  52-Week Low  50-Day Average  200-Day Average
# 487      26277.35     18837.85       25006.428        23077.352
# 488      26277.35     18837.85       25006.428        23077.352
# 489      26277.35     18837.85       25006.428        23077.352
# 490      26277.35     18837.85       25006.428        23077.352
# 491      26277.35     18837.85       25006.428        23077.352

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Week'] = df['Date'].dt.dayofweek

# %%
df['Timestamp'] = df['Date'].apply(lambda x: x.timestamp())

# %%
df = df.drop(columns = ['Date', 'Dividends', 'Stock Splits'])
df.head()
# Out:
#            Open          High           Low         Close  Volume  \
# 0  17102.099609  17114.650391  16855.550781  16887.349609  278400
# 1  17147.449219  17287.300781  17117.300781  17274.300781  226000
# 2  17379.250000  17428.800781  17315.650391  17331.800781  265500
# 3  17287.199219  17337.349609  17216.949219  17314.650391  216300
# 4  17094.349609  17280.150391  17064.699219  17241.000000  234000
#
#    Previous Close  52-Week High  52-Week Low  50-Day Average  200-Day Average  \
# 0        25810.85      26277.35     18837.85       25006.428        23077.352
# 1        25810.85      26277.35     18837.85       25006.428        23077.352
# 2        25810.85      26277.35     18837.85       25006.428        23077.352
# 3        25810.85      26277.35     18837.85       25006.428        23077.352
# 4        25810.85      26277.35     18837.85       25006.428        23077.352
#
#    Day  Month  Year  Week     Timestamp
# 0    3     10  2022     0  1.664735e+09
# 1    4     10  2022     1  1.664822e+09
# 2    6     10  2022     3  1.664995e+09
# 3    7     10  2022     4  1.665081e+09
# 4   10     10  2022     0  1.665340e+09

# %%
x = df.drop(['Close'], axis = 1)
y = df['Close']

# %%
x_sequences = []
y_sequences = []

# %%
sequence_length = 5

# %%
for i in range(sequence_length, len(x)):
    x_sequences.append(x[i-sequence_length:i])
    y_sequences.append(y[i])

# %%
x_sequences = np.array(x_sequences)
y_sequences = np.array(y_sequences)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sequences, y_sequences, test_size=0.2, shuffle=False)

# %%
scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

# %%
x_train_scaled = scaler_x.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1))

# %%
x_test_scaled = scaler_x.transform(x_test.reshape(-1, x_test.shape[-1])).reshape(x_test.shape)
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Input, Dense, Dropout
import matplotlib.pyplot as plt
# Out:
# 2024-10-05 20:55:43.429189: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-05 20:55:43.430110: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-05 20:55:43.433490: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-05 20:55:43.443695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-05 20:55:43.460390: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-05 20:55:43.465191: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-05 20:55:43.478479: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-05 20:55:44.247798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
input_shape = (x_train.shape[1], x_train.shape[2])

# %%
model = Sequential([
    Input(shape=input_shape),
    LSTM(500, activation='relu', return_sequences=True),
    Dropout(0.1),
    LSTM(500, activation='relu', return_sequences=True),
    Dropout(0.1),
    LSTM(500, activation='relu', return_sequences=False),
    Dropout(0.1),
    Dense(1)
])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728141945.190833  594598 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-05 20:55:45.194013: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(
    x_train_scaled,
    y_train_scaled,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1232 - val_loss: 0.1105
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0151 - val_loss: 0.0084
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0019 - val_loss: 0.0038
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0016 - val_loss: 0.0046
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0018 - val_loss: 0.0074
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0017 - val_loss: 0.0107
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0020 - val_loss: 0.0119
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0013 - val_loss: 0.0073
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - val_loss: 0.0078
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0013 - val_loss: 0.0096
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - val_loss: 0.0068
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.8661e-04 - val_loss: 0.0024
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010 - val_loss: 0.0067
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0012 - val_loss: 0.0055
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0011 - val_loss: 0.0075
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.1800e-04 - val_loss: 0.0025
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0017 - val_loss: 0.0079
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.0634e-04 - val_loss: 0.0039
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0010 - val_loss: 0.0020
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.8028e-04 - val_loss: 0.0042
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.5889e-04 - val_loss: 0.0027
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.3356e-04 - val_loss: 0.0048
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 0.0033
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.4468e-04 - val_loss: 0.0015
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0010 - val_loss: 0.0082
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 9.1927e-04 - val_loss: 0.0020
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.1569e-04 - val_loss: 0.0040
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.6271e-04 - val_loss: 0.0020
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.7916e-04 - val_loss: 0.0015
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.9076e-04 - val_loss: 0.0017
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.3277e-04 - val_loss: 0.0016
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010 - val_loss: 0.0042
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0025 - val_loss: 0.0083
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.6983e-04 - val_loss: 0.0027
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.3648e-04 - val_loss: 0.0033
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 8.9909e-04 - val_loss: 0.0014
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.3244e-04 - val_loss: 0.0021
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.6231e-04 - val_loss: 0.0016
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.2572e-04 - val_loss: 0.0049
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.0357e-04 - val_loss: 0.0015
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.9274e-04 - val_loss: 0.0031
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.4641e-04 - val_loss: 0.0016
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.3678e-04 - val_loss: 0.0016
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.7033e-04 - val_loss: 0.0042
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.0980e-04 - val_loss: 0.0017
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.2215e-04 - val_loss: 0.0026
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.5029e-04 - val_loss: 0.0040
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.4873e-04 - val_loss: 0.0014
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.8273e-04 - val_loss: 0.0029
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.8312e-04 - val_loss: 0.0021
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.0079e-04 - val_loss: 0.0017
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.5235e-04 - val_loss: 0.0017

# %%
y_pred_scaled = model.predict(x_test_scaled)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, color='blue', label='Actual closing price')
plt.plot(y_pred, color='red', label='Predicted closing price')
plt.title('Stock Price Prediction using LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
model.save('lstm_stock_prediction_2.0.keras')
